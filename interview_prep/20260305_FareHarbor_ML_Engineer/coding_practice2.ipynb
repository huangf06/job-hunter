# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer_data.csv')

# %%
df.describe()
# Out:
#        customer_id  recency_days  frequency      monetary  avg_order_value  \
# count   500.000000    500.000000   500.0000    500.000000       500.000000
# mean    250.500000     93.972000     9.1400   3896.735356       160.562033
# std     144.481833     96.140674     6.8236   4061.794513       121.313211
# min       1.000000      1.000000     1.0000     59.906314        20.150391
# 25%     125.750000     21.000000     4.0000    901.803721        79.452388
# 50%     250.500000     51.000000     7.0000   2268.151826       112.365322
# 75%     375.250000    148.000000    12.2500   4982.842854       200.866523
# max     500.000000    358.000000    29.0000  14962.536998       493.853159
#
#        tenure_months
# count     500.000000
# mean       24.794000
# std        15.449302
# min         1.000000
# 25%        10.000000
# 50%        25.000000
# 75%        36.000000
# max        59.000000
